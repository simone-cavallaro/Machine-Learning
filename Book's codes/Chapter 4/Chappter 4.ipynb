# %% [markdown]
# ## Creating your own embeddings using Gensim (page 110, note 141)

# %%
import gensim.downloader as api
from gensim.models import Word2Vec

dataset = api.load('text8')
model = Word2Vec(dataset)
model.save("data/text8-word2vec.bin")

# %% [markdown]
# ## Exploring the embedding space with Gensim (page 111, note 142)

# %%
from gensim.models import KeyedVectors

model = KeyedVectors.load("data/text8-word2vec.bin")
word_vectors = model.wv

# get words in the vocabulary
words = word_vectors.index_to_key
print([x for i, x in enumerate(words) if i < 10])
assert("king" in words)
# Out:
# ['the', 'of', 'and', 'one', 'in', 'a', 'to', 'zero', 'nine', 'two']

# %%
def print_most_similar(word_conf_pairs, k):
    for i, (word, conf) in enumerate(word_conf_pairs):
        print("{:.3f} {:s}".format(conf, word))
        if i >= k-1:
            break
    if k < len(word_conf_pairs):
        print("...")

# %%
print("# words similar to king")
print_most_similar(word_vectors.most_similar("king"), 5)
# Out:
# # words similar to king
# 0.771 prince
# 0.700 queen
# 0.692 kings
# 0.691 emperor
# 0.683 throne
# ...

# %%
print("# vector arithmetic with words (cosine similarity)")
print("# france + berlin - paris = ?")
print_most_similar(word_vectors.most_similar(
    positive=["france", "berlin"], negative=["paris"]), 1
)

print("# vector arithmetic with words (Levy and Goldberg)")
print("# france + berlin - paris = ?")
print_most_similar(word_vectors.most_similar_cosmul(
    positive=["france", "berlin"], negative=["paris"]), 1
)
# Out:
# # vector arithmetic with words (cosine similarity)
# # france + berlin - paris = ?
# 0.787 germany
# ...
# # vector arithmetic with words (Levy and Goldberg)
# # france + berlin - paris = ?
# 0.964 germany
# ...

# %%
print("# find odd one out")
print("# [hindus, parsis, singapore, christians]")
print(word_vectors.doesnt_match(["hindus", "parsis", 
    "singapore", "christians"]))
# Out:
# # find odd one out
# # [hindus, parsis, singapore, christians]
# singapore

# %%
print("# similarity between words")
for word in ["woman", "dog", "whale", "tree"]:
    print("similarity({:s}, {:s}) = {:.3f}".format(
        "man", word,
        word_vectors.similarity("man", word)
    ))
# Out:
# # similarity between words
# similarity(man, woman) = 0.731
# similarity(man, dog) = 0.415
# similarity(man, whale) = 0.246
# similarity(man, tree) = 0.239

# %%
print("# similar by word")
print(print_most_similar(
    word_vectors.similar_by_word("singapore"), 5)
)
# Out:
# # similar by word
# 0.887 malaysia
# 0.836 indonesia
# 0.832 uganda
# 0.828 zambia
# 0.824 tanzania
# ...
# None

# %%
print("# distance between vectors")
print("distance(singapore, malaysia) = {:.3f}".format(
    word_vectors.distance("singapore", "malaysia")
))
# Out:
# # distance between vectors
# distance(singapore, malaysia) = 0.113

# %%
vec_song = word_vectors["song"]
print("\n# output vector obtained directly, shape:", vec_song)

vec_song_2 = word_vectors.get_vector("song", norm=True)
print("# output vector obtained using get_vector, shape:", vec_song_2)
# Out:
# # output vector obtained directly, shape: [ 0.03526767 -1.5429566   0.52488524 -0.07064199 -0.22901534  0.35168254
#  -1.6209706  -1.4823098   0.41852486  3.217371   -1.4646112   0.6030418
#   0.99299425  1.049187    1.3404422   1.1903654   1.6618329  -0.17624518
#   1.2248626   0.2407499  -3.9759154   0.43350604 -0.31306309  2.144331
#  -3.0657876   0.6299651   1.0452162   0.8772226   0.83636916 -0.8365901
#   0.5945675  -0.7676213   2.427037   -0.10259538 -1.3966905   0.9825568
#   0.01358617  1.8889152  -3.0323842  -0.6807603  -0.3904169  -1.1202602
#   0.47667116  0.40947914 -0.6424973  -1.0822723  -1.5995234   2.2822142
#  -1.3017199  -0.20081589  1.1448538   2.5242095   0.39322615  0.08290467
#  -0.5089469   0.732053    0.06952075 -1.0101626   1.5235263  -1.8280276
#  -0.6033768   1.2870709  -1.1769928   2.5876875  -0.944125    0.36414582
#  -2.958802   -0.12277306 -0.79001653 -0.2364631   4.7476745  -3.197223
#   0.36921394 -1.0713817   1.7333086  -1.6508862   3.216476   -0.24987298
#   0.4896203   1.0722245  -1.9166588   0.36338782  2.0280223  -0.27460504
#  -1.5194625  -0.69607     0.9939513   3.1608803  -1.0575539   0.70498216
#   0.15256873 -1.7561003   0.05035508  1.2641968   2.4915483  -1.7551435
#  -1.442253    3.791718    0.1344966   2.7952774 ]
# # output vector obtained using get_vector, shape: [ 0.00223447 -0.0977577   0.03325536 -0.00447569 -0.01450981  0.02228169
#  -0.10270046 -0.09391528  0.02651664  0.20384422 -0.09279393  0.03820715
#   0.06291352  0.06647374  0.08492691  0.07541844  0.10528939 -0.01116643
#   0.07760409  0.01525328 -0.2519036   0.02746581 -0.01983486  0.1358592
#  -0.19424029  0.03991294  0.06622217  0.05557853  0.05299016 -0.05300416
#   0.03767024 -0.04863448  0.15377071 -0.00650018 -0.08849066  0.06225223
#   0.00086078  0.11967672 -0.19212393 -0.0431312  -0.02473579 -0.07097676
#   0.03020064  0.02594353 -0.04070695 -0.06856994 -0.10134162  0.14459512
#  -0.08247357 -0.01272317  0.07253495  0.15992731  0.02491378  0.00525262
#  -0.03224554  0.04638096  0.00440465 -0.06400126  0.09652665 -0.11581905
#  -0.03822838  0.08154544 -0.07457118  0.16394912 -0.05981729  0.02307133
#  -0.18746196 -0.00777858 -0.05005338 -0.01498168  0.30080023 -0.20256768
#   0.02339243 -0.06787995  0.1098179  -0.10459583  0.2037875  -0.0158313
#   0.03102106  0.06793334 -0.12143449  0.0230233   0.1284902  -0.01739826
#  -0.09626917 -0.04410117  0.06297415  0.20026511 -0.06700385  0.04466582
#   0.00966636 -0.11126192  0.00319037  0.0800962   0.15785798 -0.1112013
#  -0.09137738  0.24023333  0.00852135  0.17710146]
